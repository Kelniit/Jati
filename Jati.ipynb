# %% [markdown]
# <a href="https://colab.research.google.com/github/Kelniit/Jati/blob/main/Jati.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance --quiet

import yfinance as yf

import warnings

warnings.filterwarnings("ignore")

# %%
origin = yf.download("^GSPC", start="2022-01-01", end="2024-11-30", progress=False)

origin.iloc[:5]
# Out:
# Price         Adj Close        Close         High          Low         Open  \
# Ticker            ^GSPC        ^GSPC        ^GSPC        ^GSPC        ^GSPC
# Date
# 2022-01-03  4796.560059  4796.560059  4796.640137  4758.169922  4778.140137
# 2022-01-04  4793.540039  4793.540039  4818.620117  4774.270020  4804.509766
# 2022-01-05  4700.580078  4700.580078  4797.700195  4699.439941  4787.990234
# 2022-01-06  4696.049805  4696.049805  4725.009766  4671.259766  4693.390137
# 2022-01-07  4677.029785  4677.029785  4707.950195  4662.740234  4697.660156
#
# Price           Volume
# Ticker           ^GSPC
# Date
# 2022-01-03  3831020000
# 2022-01-04  4683170000
# 2022-01-05  4887960000
# 2022-01-06  4295280000
# 2022-01-07  4181510000

# %%
origin.tail()
# Out:
# Price         Adj Close        Close         High          Low         Open  \
# Ticker            ^GSPC        ^GSPC        ^GSPC        ^GSPC        ^GSPC
# Date
# 2024-11-22  5969.339844  5969.339844  5972.899902  5944.359863  5944.359863
# 2024-11-25  5987.370117  5987.370117  6020.750000  5963.910156  5992.279785
# 2024-11-26  6021.629883  6021.629883  6025.419922  5992.270020  6000.029785
# 2024-11-27  5998.740234  5998.740234  6020.160156  5984.870117  6014.109863
# 2024-11-29  6032.379883  6032.379883  6044.169922  6003.979980  6003.979980
#
# Price           Volume
# Ticker           ^GSPC
# Date
# 2024-11-22  4141420000
# 2024-11-25  5633150000
# 2024-11-26  3835170000
# 2024-11-27  3363340000
# 2024-11-29  2444420000

# %%
null = origin.isnull().sum()

null.sum()
# Out:
# 0

# %%
oriclose = origin["Close"]

oriclose.iloc[:5]
# Out:
# Ticker            ^GSPC
# Date
# 2022-01-03  4796.560059
# 2022-01-04  4793.540039
# 2022-01-05  4700.580078
# 2022-01-06  4696.049805
# 2022-01-07  4677.029785

# %%
import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8-whitegrid")

title = "Standard & Poor's 500 Close Stock 2022 - 2024"

xlabel = "Tanggal"; ylabel = "Close Stock"

plot = oriclose["^GSPC"].plot.line(title=title, xlabel=xlabel, ylabel=ylabel, figsize=(8, 6), rot=0);
